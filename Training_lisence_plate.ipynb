# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/PlateRecog/v4/darknet/
# !rm darknet
# !make
# !chmod +x ./darknet
# Out:
# /content/gdrive/MyDrive/PlateRecog/v4/darknet
# chmod +x *.sh
# ...

# %%
# !rm /content/darknet/backup -r
# !ln -s /content/drive/'My Drive'/PlateRecog/backup /content/darknet

# %%
# Train
# %cd /content/gdrive/MyDrive/PlateRecog/v4/darknet/
# !./darknet detector train yolo.data cfg/yolov4-custom.cfg backup/yolov4-custom_last.weights -dont_show
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 0.003886, iou_loss = 0.000000, total_loss = 0.003886
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.000000), count: 1, class_loss = 0.001955, iou_loss = 0.000000, total_loss = 0.001955
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.000000), count: 1, class_loss = 0.000376, iou_loss = 0.000000, total_loss = 0.000376
#  total_bbox = 264345, rewritten_bbox = 0.000378 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.670254), count: 2, class_loss = 0.631121, iou_loss = 41.307991, total_loss = 41.939110
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.732786), count: 2, class_loss = 0.592988, iou_loss = 20.387285, total_loss = 20.980274
# ...
